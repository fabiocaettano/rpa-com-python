# %% [markdown]
# Teste Pandas

# %%
# %pip install pandas

# %%
# importa a biblioteca pandas
import pandas as pd
tabela = pd.read_csv("cancelamentos.csv")
display(tabela)

# %%
# exclui uma coluna
tabela = tabela.drop(columns=["CustomerID"])
display(tabela)

# %%
# exibe o dataframe
display(tabela.info())

# %%
# Remover linhas com valores ausentes
tabela = tabela.dropna()
display(tabela.info())

# %%
display(tabela["cancelou"].value_counts())
display(tabela["cancelou"].value_counts(normalize=True))

# %%
tabela = tabela[tabela["duracao_contrato"]!="Monthly"]
display(tabela)
# Out:
#        idade    sexo  tempo_como_cliente  frequencia_uso  ligacoes_callcenter  \
# 0       23.0    Male                13.0            22.0                  2.0
# 2       30.0    Male                 7.0             1.0                  0.0
# 3       26.0    Male                40.0             5.0                  3.0
# 4       27.0  Female                17.0            30.0                  5.0
# 6       49.0    Male                 6.0             7.0                  0.0
# ...      ...     ...                 ...             ...                  ...
# 49994   63.0    Male                16.0            24.0                  2.0
# 49995   62.0  Female                35.0             7.0                  2.0
# 49996   36.0    Male                43.0            21.0                  2.0
# 49998   40.0  Female                14.0            19.0                  1.0
# 49999   64.0    Male                41.0            29.0                  5.0
#
#        dias_atraso assinatura duracao_contrato  total_gasto  \
# 0              1.0   Standard           Annual       909.58
# 2              8.0      Basic           Annual       768.78
# 3              8.0    Premium           Annual       398.00
# 4              6.0      Basic           Annual       507.00
# 6              0.0   Standard           Annual       751.00
# ...            ...        ...              ...          ...
# 49994         18.0   Standard        Quarterly       442.00
# 49995          8.0      Basic           Annual       232.00
# 49996         30.0      Basic        Quarterly       928.00
# 49998         17.0    Premium        Quarterly       826.76
# 49999          9.0      Basic        Quarterly       700.38
#
#        meses_ultima_interacao  cancelou
# 0                        23.0       0.0
# 2                         7.0       0.0
# 3                        12.0       1.0
# 4                        15.0       1.0
# 6                        11.0       0.0
# ...                       ...       ...
# 49994                    26.0       1.0
# 49995                    15.0       1.0
# 49996                    30.0       1.0
# 49998                    12.0       0.0
# 49999                    18.0       1.0
#
# [40112 rows x 11 columns]

# %%
tabela = tabela[tabela["ligacoes_callcenter"]<=4]
display(tabela)
# Out:
#        idade    sexo  tempo_como_cliente  frequencia_uso  ligacoes_callcenter  \
# 0       23.0    Male                13.0            22.0                  2.0
# 2       30.0    Male                 7.0             1.0                  0.0
# 3       26.0    Male                40.0             5.0                  3.0
# 6       49.0    Male                 6.0             7.0                  0.0
# 7       33.0    Male                15.0            18.0                  1.0
# ...      ...     ...                 ...             ...                  ...
# 49992   37.0    Male                46.0            29.0                  2.0
# 49994   63.0    Male                16.0            24.0                  2.0
# 49995   62.0  Female                35.0             7.0                  2.0
# 49996   36.0    Male                43.0            21.0                  2.0
# 49998   40.0  Female                14.0            19.0                  1.0
#
#        dias_atraso assinatura duracao_contrato  total_gasto  \
# 0              1.0   Standard           Annual       909.58
# 2              8.0      Basic           Annual       768.78
# 3              8.0    Premium           Annual       398.00
# 6              0.0   Standard           Annual       751.00
# 7             20.0   Standard           Annual       839.71
# ...            ...        ...              ...          ...
# 49992          9.0   Standard        Quarterly       517.86
# 49994         18.0   Standard        Quarterly       442.00
# 49995          8.0      Basic           Annual       232.00
# 49996         30.0      Basic        Quarterly       928.00
# 49998         17.0    Premium        Quarterly       826.76
#
#        meses_ultima_interacao  cancelou
# 0                        23.0       0.0
# 2                         7.0       0.0
# 3                        12.0       1.0
# 6                        11.0       0.0
# 7                        25.0       0.0
# ...                       ...       ...
# 49992                     3.0       0.0
# 49994                    26.0       1.0
# 49995                    15.0       1.0
# 49996                    30.0       1.0
# 49998                    12.0       0.0
#
# [29123 rows x 11 columns]

# %%
tabela = tabela[tabela["dias_atraso"]<=20]
display(tabela)
# Out:
#        idade    sexo  tempo_como_cliente  frequencia_uso  ligacoes_callcenter  \
# 0       23.0    Male                13.0            22.0                  2.0
# 2       30.0    Male                 7.0             1.0                  0.0
# 3       26.0    Male                40.0             5.0                  3.0
# 6       49.0    Male                 6.0             7.0                  0.0
# 8       19.0  Female                59.0            19.0                  1.0
# ...      ...     ...                 ...             ...                  ...
# 49983   22.0  Female                 7.0            19.0                  3.0
# 49984   40.0  Female                57.0            22.0                  0.0
# 49985   50.0    Male                31.0            12.0                  3.0
# 49992   37.0    Male                46.0            29.0                  2.0
# 49995   62.0  Female                35.0             7.0                  2.0
#
#        dias_atraso assinatura duracao_contrato  total_gasto  \
# 0              1.0   Standard           Annual       909.58
# 2              8.0      Basic           Annual       768.78
# 3              8.0    Premium           Annual       398.00
# 6              0.0   Standard           Annual       751.00
# 8              4.0      Basic        Quarterly       543.93
# ...            ...        ...              ...          ...
# 49983          0.0      Basic           Annual       550.00
# 49984          0.0    Premium           Annual       711.97
# 49985          0.0   Standard           Annual       794.10
# 49992          9.0   Standard        Quarterly       517.86
# 49995          8.0      Basic           Annual       232.00
#
#        meses_ultima_interacao  cancelou
# 0                        23.0       0.0
# 2                         7.0       0.0
# 3                        12.0       1.0
# 6                        11.0       0.0
# 8                         7.0       0.0
# ...                       ...       ...
# 49983                     3.0       1.0
# 49984                     4.0       0.0
# 49985                    18.0       0.0
# 49992                     3.0       0.0
# 49995                    15.0       1.0
#
# [13585 rows x 11 columns]

# %%
display(tabela["cancelou"].value_counts())
# em percentual
display(tabela["cancelou"].value_counts(normalize=True))
# Out:
# cancelou
# 0.0    11099
# 1.0     2486
# Name: count, dtype: int64
# cancelou
# 0.0    0.817004
# 1.0    0.182996
# Name: proportion, dtype: float64
